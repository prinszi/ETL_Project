# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into dataframes

# %%
#read and confirm files from emissions dataset
emission1980_file = "annual_aqi_by_county_1980.csv"
emission1985_file = "annual_aqi_by_county_1985.csv"
emission1990_file = "annual_aqi_by_county_1990.csv"
emission1995_file = "annual_aqi_by_county_1995.csv"
emission2000_file = "annual_aqi_by_county_2000.csv"
emission2005_file = "annual_aqi_by_county_2005.csv"
emission2010_file = "annual_aqi_by_county_2010.csv"
emission2014_file = "annual_aqi_by_county_2014.csv"

emission1980_data_df = pd.read_csv(emission1980_file)
emission1985_data_df = pd.read_csv(emission1985_file)
emission1990_data_df = pd.read_csv(emission1990_file)
emission1995_data_df = pd.read_csv(emission1995_file)
emission2000_data_df = pd.read_csv(emission2000_file)
emission2005_data_df = pd.read_csv(emission2005_file)
emission2010_data_df = pd.read_csv(emission2010_file)
emission2014_data_df = pd.read_csv(emission2014_file)

# %%
#join the emissions dataset
emission_all_df = pd.concat((emission1980_data_df ,emission1985_data_df, emission1990_data_df, emission1995_data_df, \
                  emission2000_data_df, emission2005_data_df, emission2010_data_df, emission2014_data_df), join="outer")
emission_all_df.head()
# Out:
#      State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama     Autauga  1980            179        122             35
# 1  Alabama     Colbert  1980            274        127             45
# 2  Alabama     Jackson  1980            366         85            110
# 3  Alabama   Jefferson  1980            343        171            109
# 4  Alabama  Lauderdale  1980            274        120             58
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                   18               4                    0
# 1                                   63              39                    0
# 2                                   92              79                    0
# 3                                   37              19                    7
# 4                                   77              19                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0               0      177                  108          40        0
# 1               0      200                  165          56        0
# 2               0      200                  200          94        0
# 3               0      221                  140          51      207
# 4               0      200                  139          56        0
#
#    Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10
# 0         0         122        57           0          0
# 1         0           0       274           0          0
# 2         0           0       366           0          0
# 3         0         136         0           0          0
# 4         0           0       274           0          0

# %%
#read and confirm files from mortality dataset
mortality_file = "mort.csv"
mortality_data_df = pd.read_csv(mortality_file)
mortality_data_df.head()
# Out:
#                   Location    FIPS            Category  Mortality Rate, 1980*  \
# 0            United States     NaN  Neonatal disorders                   9.18
# 1                  Alabama     1.0  Neonatal disorders                  11.03
# 2  Autauga County, Alabama  1001.0  Neonatal disorders                   9.58
# 3  Baldwin County, Alabama  1003.0  Neonatal disorders                   8.75
# 4  Barbour County, Alabama  1005.0  Neonatal disorders                  12.30
#
#    Mortality Rate, 1980* (Min)  Mortality Rate, 1980* (Max)  \
# 0                         8.83                         9.93
# 1                        10.57                        12.00
# 2                         8.37                        11.02
# 3                         7.86                         9.81
# 4                        10.64                        14.15
#
#    Mortality Rate, 1985*  Mortality Rate, 1985* (Min)  \
# 0                   6.91                         6.73
# 1                   8.51                         8.25
# 2                   7.50                         6.56
# 3                   6.54                         5.88
# 4                   9.26                         8.13
#
#    Mortality Rate, 1985* (Max)  Mortality Rate, 1990*  ...  \
# 0                         7.36                   6.09  ...
# 1                         9.12                   7.52  ...
# 2                         8.58                   6.76  ...
# 3                         7.27                   5.76  ...
# 4                        10.60                   8.12  ...
#
#    Mortality Rate, 2005* (Max)  Mortality Rate, 2010*  \
# 0                         4.55                   3.75
# 1                         6.52                   5.58
# 2                         6.30                   4.83
# 3                         5.03                   4.02
# 4                         7.89                   5.99
#
#    Mortality Rate, 2010* (Min)  Mortality Rate, 2010* (Max)  \
# 0                         3.43                         3.85
# 1                         5.16                         5.78
# 2                         4.19                         5.49
# 3                         3.53                         4.48
# 4                         5.16                         6.84
#
#    Mortality Rate, 2014*  Mortality Rate, 2014* (Min)  \
# 0                   3.32                         3.02
# 1                   5.10                         4.67
# 2                   4.56                         3.96
# 3                   3.68                         3.25
# 4                   5.43                         4.63
#
#    Mortality Rate, 2014* (Max)  % Change in Mortality Rate, 1980-2014  \
# 0                         3.45                                 -63.85
# 1                         5.32                                 -53.82
# 2                         5.21                                 -52.43
# 3                         4.08                                 -57.97
# 4                         6.24                                 -55.86
#
#    % Change in Mortality Rate, 1980-2014 (Min)  \
# 0                                       -68.95
# 1                                       -60.08
# 2                                       -60.01
# 3                                       -64.96
# 4                                       -62.49
#
#    % Change in Mortality Rate, 1980-2014 (Max)
# 0                                       -61.55
# 1                                       -50.77
# 2                                       -46.16
# 3                                       -52.87
# 4                                       -50.32
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Transform mortality dataframe

# %%
# edit county names in mortality dataset
mortality_data_df['county']= mortality_data_df.Location.replace({' County,':''}, regex=True)
mortality_data_df.head()
# Out:
#                   Location    FIPS            Category  Mortality Rate, 1980*  \
# 0            United States     NaN  Neonatal disorders                   9.18
# 1                  Alabama     1.0  Neonatal disorders                  11.03
# 2  Autauga County, Alabama  1001.0  Neonatal disorders                   9.58
# 3  Baldwin County, Alabama  1003.0  Neonatal disorders                   8.75
# 4  Barbour County, Alabama  1005.0  Neonatal disorders                  12.30
#
#    Mortality Rate, 1980* (Min)  Mortality Rate, 1980* (Max)  \
# 0                         8.83                         9.93
# 1                        10.57                        12.00
# 2                         8.37                        11.02
# 3                         7.86                         9.81
# 4                        10.64                        14.15
#
#    Mortality Rate, 1985*  Mortality Rate, 1985* (Min)  \
# 0                   6.91                         6.73
# 1                   8.51                         8.25
# 2                   7.50                         6.56
# 3                   6.54                         5.88
# 4                   9.26                         8.13
#
#    Mortality Rate, 1985* (Max)  Mortality Rate, 1990*  ...  \
# 0                         7.36                   6.09  ...
# 1                         9.12                   7.52  ...
# 2                         8.58                   6.76  ...
# 3                         7.27                   5.76  ...
# 4                        10.60                   8.12  ...
#
#    Mortality Rate, 2010*  Mortality Rate, 2010* (Min)  \
# 0                   3.75                         3.43
# 1                   5.58                         5.16
# 2                   4.83                         4.19
# 3                   4.02                         3.53
# 4                   5.99                         5.16
#
#    Mortality Rate, 2010* (Max)  Mortality Rate, 2014*  \
# 0                         3.85                   3.32
# 1                         5.78                   5.10
# 2                         5.49                   4.56
# 3                         4.48                   3.68
# 4                         6.84                   5.43
#
#    Mortality Rate, 2014* (Min)  Mortality Rate, 2014* (Max)  \
# 0                         3.02                         3.45
# 1                         4.67                         5.32
# 2                         3.96                         5.21
# 3                         3.25                         4.08
# 4                         4.63                         6.24
#
#    % Change in Mortality Rate, 1980-2014  \
# 0                                 -63.85
# 1                                 -53.82
# 2                                 -52.43
# 3                                 -57.97
# 4                                 -55.86
#
#    % Change in Mortality Rate, 1980-2014 (Min)  \
# 0                                       -68.95
# 1                                       -60.08
# 2                                       -60.01
# 3                                       -64.96
# 4                                       -62.49
#
#    % Change in Mortality Rate, 1980-2014 (Max)           county
# 0                                       -61.55    United States
# 1                                       -50.77          Alabama
# 2                                       -46.16  Autauga Alabama
# 3                                       -52.87  Baldwin Alabama
# 4                                       -50.32  Barbour Alabama
#
# [5 rows x 31 columns]

# %%
# Transform Emission data
emission_all_df["County"] = emission_all_df["County"].str.cat(emission_all_df["State"], sep =" ")
emission_all_df.head()
# Out:
#      State              County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama     Autauga Alabama  1980            179        122             35
# 1  Alabama     Colbert Alabama  1980            274        127             45
# 2  Alabama     Jackson Alabama  1980            366         85            110
# 3  Alabama   Jefferson Alabama  1980            343        171            109
# 4  Alabama  Lauderdale Alabama  1980            274        120             58
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                   18               4                    0
# 1                                   63              39                    0
# 2                                   92              79                    0
# 3                                   37              19                    7
# 4                                   77              19                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0               0      177                  108          40        0
# 1               0      200                  165          56        0
# 2               0      200                  200          94        0
# 3               0      221                  140          51      207
# 4               0      200                  139          56        0
#
#    Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10
# 0         0         122        57           0          0
# 1         0           0       274           0          0
# 2         0           0       366           0          0
# 3         0         136         0           0          0
# 4         0           0       274           0          0

# %% [markdown]
# ### Drop columns in both dataframes

# %%
# drop unnecessary columns (min/max)
emission_cols = ["County", "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days", "Max AQI", "Median AQI", "Days SO2", "Days PM2.5"]
emission_clean_df = emission_all_df[emission_cols].copy()
emission_clean_df = emission_clean_df.rename(columns={"County":"county", "Unhealthy Days":"unhealthy_days", 
                                                      "Very Unhealthy Days":"very_unhealthy_days", 
                                                      "Hazardous Days":"hazardous_days", "Max AQI":"max_aqi", 
                                                      "Median AQI":"median_aqi","Days SO2":"days_so2", 
                                                      "Days PM2.5":"days_pm25"})
emission_clean_df.set_index("county", inplace=True)
emission_clean_df.head()
# Out:
#                     unhealthy_days  very_unhealthy_days  hazardous_days  \
# county
# Autauga Alabama                  4                    0               0
# Colbert Alabama                 39                    0               0
# Jackson Alabama                 79                    0               0
# Jefferson Alabama               19                    7               0
# Lauderdale Alabama              19                    0               0
#
#                     max_aqi  median_aqi  days_so2  days_pm25
# county
# Autauga Alabama         177          40        57          0
# Colbert Alabama         200          56       274          0
# Jackson Alabama         200          94       366          0
# Jefferson Alabama       221          51         0          0
# Lauderdale Alabama      200          56       274          0

# %%
mortality_data_df = mortality_data_df.dropna(how="any")
mortality_data_df
mortality_data_df2 = mortality_data_df[mortality_data_df['FIPS']>1000]
mortality_data_df2.head()
# Out:
#                   Location    FIPS            Category  Mortality Rate, 1980*  \
# 2  Autauga County, Alabama  1001.0  Neonatal disorders                   9.58
# 3  Baldwin County, Alabama  1003.0  Neonatal disorders                   8.75
# 4  Barbour County, Alabama  1005.0  Neonatal disorders                  12.30
# 5     Bibb County, Alabama  1007.0  Neonatal disorders                  11.28
# 6   Blount County, Alabama  1009.0  Neonatal disorders                   6.05
#
#    Mortality Rate, 1980* (Min)  Mortality Rate, 1980* (Max)  \
# 2                         8.37                        11.02
# 3                         7.86                         9.81
# 4                        10.64                        14.15
# 5                         9.63                        13.14
# 6                         5.22                         6.97
#
#    Mortality Rate, 1985*  Mortality Rate, 1985* (Min)  \
# 2                   7.50                         6.56
# 3                   6.54                         5.88
# 4                   9.26                         8.13
# 5                   8.88                         7.57
# 6                   4.80                         4.18
#
#    Mortality Rate, 1985* (Max)  Mortality Rate, 1990*  ...  \
# 2                         8.58                   6.76  ...
# 3                         7.27                   5.76  ...
# 4                        10.60                   8.12  ...
# 5                        10.27                   7.92  ...
# 6                         5.47                   4.42  ...
#
#    Mortality Rate, 2010*  Mortality Rate, 2010* (Min)  \
# 2                   4.83                         4.19
# 3                   4.02                         3.53
# 4                   5.99                         5.16
# 5                   6.29                         5.32
# 6                   3.70                         3.16
#
#    Mortality Rate, 2010* (Max)  Mortality Rate, 2014*  \
# 2                         5.49                   4.56
# 3                         4.48                   3.68
# 4                         6.84                   5.43
# 5                         7.27                   5.89
# 6                         4.23                   3.52
#
#    Mortality Rate, 2014* (Min)  Mortality Rate, 2014* (Max)  \
# 2                         3.96                         5.21
# 3                         3.25                         4.08
# 4                         4.63                         6.24
# 5                         4.98                         6.85
# 6                         2.99                         4.06
#
#    % Change in Mortality Rate, 1980-2014  \
# 2                                 -52.43
# 3                                 -57.97
# 4                                 -55.86
# 5                                 -47.76
# 6                                 -41.80
#
#    % Change in Mortality Rate, 1980-2014 (Min)  \
# 2                                       -60.01
# 3                                       -64.96
# 4                                       -62.49
# 5                                       -56.13
# 6                                       -52.54
#
#    % Change in Mortality Rate, 1980-2014 (Max)           county
# 2                                       -46.16  Autauga Alabama
# 3                                       -52.87  Baldwin Alabama
# 4                                       -50.32  Barbour Alabama
# 5                                       -40.11     Bibb Alabama
# 6                                       -33.49   Blount Alabama
#
# [5 rows x 31 columns]

# %%
mort_cols = ["county", "Category", "Mortality Rate, 1980*", "Mortality Rate, 1985*", "Mortality Rate, 1990*", 
             "Mortality Rate, 1995*", "Mortality Rate, 2000*", "Mortality Rate, 2005*", "Mortality Rate, 2010*", 
             "Mortality Rate, 2014*", "% Change in Mortality Rate, 1980-2014"]
mort_clean_df = mortality_data_df2[mort_cols].copy()
mort_clean_df = mort_clean_df.rename(columns={"county":"county", "Category":"category", "Mortality Rate, 1980*":"mort_1980", 
                                              "Mortality Rate, 1985*":"mort_1985", "Mortality Rate, 1990*":"mort_1990", 
                                              "Mortality Rate, 1995*":"mort_1995", "Mortality Rate, 2000*":"mort_2000", 
                                              "Mortality Rate, 2005*":"mort_2005", "Mortality Rate, 2010*":"mort_2010", 
                                              "Mortality Rate, 2014*":"mort_2014", "% Change in Mortality Rate, 1980-2014":"percent_mort_change"})
mort_clean_df.set_index("county", inplace=True)
mort_clean_df.head()
# Out:
#                            category  mort_1980  mort_1985  mort_1990  \
# county
# Autauga Alabama  Neonatal disorders       9.58       7.50       6.76
# Baldwin Alabama  Neonatal disorders       8.75       6.54       5.76
# Barbour Alabama  Neonatal disorders      12.30       9.26       8.12
# Bibb Alabama     Neonatal disorders      11.28       8.88       7.92
# Blount Alabama   Neonatal disorders       6.05       4.80       4.42
#
#                  mort_1995  mort_2000  mort_2005  mort_2010  mort_2014  \
# county
# Autauga Alabama       5.24       5.26       5.55       4.83       4.56
# Baldwin Alabama       4.65       4.56       4.55       4.02       3.68
# Barbour Alabama       6.60       6.65       6.90       5.99       5.43
# Bibb Alabama          6.44       6.59       7.14       6.29       5.89
# Blount Alabama        3.68       3.78       4.06       3.70       3.52
#
#                  percent_mort_change
# county
# Autauga Alabama               -52.43
# Baldwin Alabama               -57.97
# Barbour Alabama               -55.86
# Bibb Alabama                  -47.76
# Blount Alabama                -41.80

# %% [markdown]
# ### Create database connection

# %%
rds_connection_string = "postgres:postgres@localhost:5432/ETL_Project"
#rds_connection_string = "<insert user name>:<insert password>@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['emissions', 'mortality']

# %% [markdown]
# ### Load dataframes into database

# %%
mort_clean_df.to_sql(name = 'mortality', con=engine, if_exists='append', index=True)

# %%
emission_clean_df.to_sql(name = 'county', con=engine, if_exists='append', index=True)

# %%
mort_from_sql_df = pd.read_sql_query("select * from mortality", con=engine).head()

# %%
mort_from_sql_df.set_index("id")
# Out:
#              county            category  mort_1980  mort_1985  mort_1990  \
# id
# 1   Autauga Alabama  Neonatal disorders         10          8          7
# 2   Baldwin Alabama  Neonatal disorders          9          7          6
# 3   Barbour Alabama  Neonatal disorders         12          9          8
# 4      Bibb Alabama  Neonatal disorders         11          9          8
# 5    Blount Alabama  Neonatal disorders          6          5          4
#
#     mort_1995  mort_2000  mort_2005  mort_2010  mort_2014  percent_mort_change
# id
# 1           5          5          6          5          5                  -52
# 2           5          5          5          4          4                  -58
# 3           7          7          7          6          5                  -56
# 4           6          7          7          6          6                  -48
# 5           4          4          4          4          4                  -42
